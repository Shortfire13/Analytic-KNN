# %% [markdown]
# # Import Library

# %%
import re
import pandas as pd
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
from datetime import timedelta, datetime
from sklearn.model_selection import train_test_split
import mapply #Library untuk mengaktifkan multi threading/ multi core
import joblib

# %%
mapply.init(
    n_workers=-1,
    chunk_size=2000,
    max_chunks_per_worker=8,
    progressbar=False
)

# %% [markdown]
# ## Inisialisasi Proporsi

# %%
proportion = 2
if proportion == 1:
    test_size = 0.1
elif proportion == 2:
    test_size = 0.2
elif proportion == 3:
    test_size = 0.3
elif proportion == 4:
    test_size = 0.4
else:
    test_size = 0.2

# %% [markdown]
# ## Import Corpus Stopword & Normalisasi

# %%
with open("stopword.txt") as f:
    stopwords = f.read().splitlines()
# import stopwords

# %%
with open("normalisasi.txt") as f:
    normalisasi = f.read().splitlines()
# import normalisasi

# %% [markdown]
# # Buat Fungsi Preprocessing

# %%
# Cleaning
def _cleaning(term):
    # Hapus pencatuman username    
    _term = re.sub(r"@[\w]*", "", term)
    # Hapus hyperlink  
    _term =  re.sub('((www\.[^\s]+)|(https?://[^\s]+))','URL', _term)
    # Hapus special character    
    _term = re.sub(r"[()\"#/@;:<>{}*`'+=~|.!?,]", "", _term)
    _term = re.sub('[^a-zA-Zа-яА-Я]+', ' ', _term)
    # Remove multiple space 
    _term = re.sub("\s\s+", " ", _term)
    # Remove emoticons
    _regrex_pattern = re.compile(pattern="["
                                    u"\U0001F600-\U0001F64F"  # emoticons
                                    u"\U0001F300-\U0001F5FF"  # symbols
                                    u"\U0001F680-\U0001F6FF"  # transport & map symbols
                                    u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
                                    "]+", flags=re.UNICODE)
    return re.sub(_regrex_pattern, "", _term)
    
# Casefolding (lowercase)
def _casefolding(term):
    _term = term.lower()
    return _term

# Tokenizing (token)
def _tokenizing(term):
    if not isinstance(term, str): return
    return term.split()

# Normalisasi (Ubah kata alay atau typo)
def _normalisasi(term):
    temp = term
    for w in normalisasi:
        try:
            w_ = w.split(',')
            if term.index(w_[0]):
                temp = [w_[1] if word == w_[0] else word for word in term]
        except:
            continue
    return temp

# Stopword (hapus kata tidak penting (bag of words))
def _stopword(term):
    temp = [w for w in term if not w in stopwords]
    return temp

# Steeming (pengambilan kata dasar)
def _steeming(terms):
    factory = StemmerFactory()
    stemmer = factory.create_stemmer()
    tweet = stemmer.stem(" ".join(terms))
    return tweet.split()

# Proses Text Pre-processing
def normalization(term): 
    cleaning = _cleaning(term)
    casefolding = _casefolding(cleaning)
    tokenizing = _tokenizing(casefolding)
    normalisasi = _normalisasi(tokenizing)
    stopword = _stopword(normalisasi)
    steeming = _steeming(stopword)
    return [cleaning, casefolding, tokenizing, normalisasi, stopword, steeming]

def callback(x):
    cleaning, casefolding, tokenizing, normalisasi, stopword, steeming = normalization(x)
    return pd.Series({'cleaning': cleaning, 'casefolding': casefolding, 'tokenizing': tokenizing,'normalisasi':normalisasi,'stopword': stopword,'steeming': steeming, 'cleaned': " ".join(steeming)})

# %% [markdown]
# # Import Data Training

# %%
df = pd.read_csv("project2.csv",sep=',')
df
# Out:
#                                           link   no          date  \
# 0     https://www.instagram.com/p/B9g3hvMnYrA/  171   Mar 9, 2020
# 1     https://www.instagram.com/p/B9g3hvMnYrA/  170   Mar 9, 2020
# 2     https://www.instagram.com/p/B9g3hvMnYrA/  169   Mar 9, 2020
# 3     https://www.instagram.com/p/B9g3hvMnYrA/  168   Mar 9, 2020
# 4     https://www.instagram.com/p/B9g3hvMnYrA/  167   Mar 9, 2020
# ...                                        ...  ...           ...
# 1415  https://www.instagram.com/p/CgWyjY5JkUt/    5  Jul 23, 2022
# 1416  https://www.instagram.com/p/CgWyjY5JkUt/    4  Jul 23, 2022
# 1417  https://www.instagram.com/p/CgWyjY5JkUt/    3  Jul 23, 2022
# 1418  https://www.instagram.com/p/CgWyjY5JkUt/    2  Jul 23, 2022
# 1419  https://www.instagram.com/p/CgWyjY5JkUt/    1  Jul 23, 2022
#
#               author                                            comment    id  \
# 0          zifaainnr                           Mau syuting apa kak risa  6748
# 1     lemonteasquihy                                       Ke duaa nihh  6747
# 2       sulis_saja09                                Bear nya manah??? 😍  6746
# 3           wldnaar_                 Dia smp apa sd sih bingung wkwkwks  6745
# 4         ririmwldr_            Masha and the bear versi real sigemesss  6744
# ...              ...                                                ...   ...
# 1415       myrissa12        Presiden rusia sama amerika dateng ga bang?  5332
# 1416     ginthaputri                  hebat wagub sumbar bisa terbang👍🏻  5331
# 1417   anaa_istianah  Bang maafin klo blh saran jgn pakai kuas bulu ...  5330
# 1418          p.oci_  Bang kalau Dine in tapi meja penuh terus mau m...  5329
# 1419     iqbalfarabi                                           Verified  5328
#
#      sentiment  annotator  annotation_id                   created_at  \
# 0      Neutral          1           1439  2022-08-02T13:04:33.451851Z
# 1      Neutral          1           1438  2022-08-02T13:04:25.651468Z
# 2      Neutral          1           1437  2022-08-02T13:04:20.522557Z
# 3      Neutral          1           1436  2022-08-02T13:04:15.672919Z
# 4      Neutral          1           1435  2022-08-02T13:04:07.389773Z
# ...        ...        ...            ...                          ...
# 1415  Negative          1             24  2022-07-27T15:44:08.154439Z
# 1416  Negative          1             23  2022-07-27T15:43:58.537241Z
# 1417  Positive          1             22  2022-07-27T15:43:54.650729Z
# 1418  Positive          1             21  2022-07-27T15:43:50.803404Z
# 1419   Neutral          1             20  2022-07-27T15:43:45.144974Z
#
#                        updated_at  lead_time
# 0     2022-08-02T13:04:33.451851Z      3.148
# 1     2022-08-02T13:04:25.651468Z      3.126
# 2     2022-08-02T13:04:20.522557Z      2.447
# 3     2022-08-02T13:04:15.672919Z      6.164
# 4     2022-08-02T13:04:07.389773Z      2.406
# ...                           ...        ...
# 1415  2022-07-27T15:44:08.154439Z      8.484
# 1416  2022-07-27T15:43:58.537241Z      2.756
# 1417  2022-07-27T15:43:54.650729Z      2.655
# 1418  2022-07-27T15:43:50.803404Z      4.277
# 1419  2022-07-27T15:43:45.144974Z      2.098
#
# [1420 rows x 12 columns]

# %%
#normalisasi data to table
normalization = df['comment'].mapply(callback)
df = pd.concat([df,normalization], axis=1, join='inner')
df
# Out:
#                                           link   no          date  \
# 0     https://www.instagram.com/p/B9g3hvMnYrA/  171   Mar 9, 2020
# 1     https://www.instagram.com/p/B9g3hvMnYrA/  170   Mar 9, 2020
# 2     https://www.instagram.com/p/B9g3hvMnYrA/  169   Mar 9, 2020
# 3     https://www.instagram.com/p/B9g3hvMnYrA/  168   Mar 9, 2020
# 4               masha and the bear versi real sigemesss
# ...                                                 ...
# 1415         presiden rusia sama amerika dateng ga bang
# 1416                   hebat wagub sumbar bisa terbang
# 1417  bang maafin klo blh saran jgn pakai kuas bulu ...
# 1418  bang kalau dine in tapi meja penuh terus mau m...
# 1419                                           verified
#
#                                              tokenizing  \
# 0                        [mau, syuting, apa, kak, risa]
# 1                                      [ke, duaa, nihh]
# 2                                    [bear, nya, manah]
# 3            [dia, smp, apa, sd, sih, bingung, wkwkwks]
# 4       [masha, and, the, bear, versi, real, sigemesss]
# ...                                                 ...
# 1415  [presiden, rusia, sama, amerika, dateng, ga, b...
# 1416              [hebat, wagub, sumbar, bisa, terbang]
# 1417  [bang, maafin, klo, blh, saran, jgn, pakai, ku...
# 1418  [bang, kalau, dine, in, tapi, meja, penuh, ter...
# 1419                                         [verified]
#
#                                             normalisasi  \
# 0                        [mau, syuting, apa, kak, risa]
# 1                                       [ke, duaa, nih]
# 2                                    [bear, nya, manah]
# 3         [dia, sampai, apa, sd, sih, bingung, wkwkwks]
# 4       [masha, and, the, bear, versi, real, sigemesss]
# ...                                                 ...
# 1415  [presiden, rusia, sama, amerika, dateng, engga...
# 1416              [hebat, wagub, sumbar, bisa, terbang]
# 1417  [bang, maafin, klo, blh, saran, jgn, pakai, ku...
# 1418  [bang, kalau, dine, in, tapi, meja, penuh, ter...
# 1419                                         [verified]
#
#                                                stopword  \
# 0                                  [syuting, kak, risa]
# 1                                           [duaa, nih]
# 2                                    [bear, nya, manah]
# 3                           [sd, sih, bingung, wkwkwks]
# 4       [masha, and, the, bear, versi, real, sigemesss]
# ...                                                 ...
# 1415           [presiden, rusia, amerika, dateng, bang]
# 1416                    [hebat, wagub, sumbar, terbang]
# 1417  [bang, maafin, klo, blh, saran, jgn, pakai, ku...
# 1418     [bang, dine, in, meja, penuh, makannya, motor]
# 1419                                         [verified]
#
#                                                steeming  \
# 0                                  [syuting, kak, risa]
# 1                                           [duaa, nih]
# 2                                    [bear, nya, manah]
# 3                           [sd, sih, bingung, wkwkwks]
# 4       [masha, and, the, bear, versi, real, sigemesss]
# ...                                                 ...
# 1415           [presiden, rusia, amerika, dateng, bang]
# 1416                    [hebat, wagub, sumbar, terbang]
# 1417  [bang, maafin, klo, blh, saran, jgn, pakai, ku...
# 1418        [bang, dine, in, meja, penuh, makan, motor]
# 1419                                         [verified]
#
#                                                 cleaned
# 0                                      syuting kak risa
# 1                                              duaa nih
# 2                                        bear nya manah
# 3                                sd sih bingung wkwkwks
# 4               masha and the bear versi real sigemesss
# ...                                                 ...
# 1415                 presiden rusia amerika dateng bang
# 1416                         hebat wagub sumbar terbang
# 1417  bang maafin klo blh saran jgn pakai kuas bulu ...
# 1418                bang dine in meja penuh makan motor
# 1419                                           verified
#
# [1420 rows x 19 columns]

# %% [markdown]
# ## Split Data Test & Data Latih

# %%
#pengubahan data training
train, test = train_test_split(df, test_size=test_size)
train.head()
# Out:
#                                           link   no          date  \
# 33    https://www.instagram.com/p/B9g3hvMnYrA/  138   Mar 9, 2020
# 1311  https://www.instagram.com/p/CgWyjY5JkUt/  109  Jul 23, 2022
# 102   https://www.instagram.com/p/B9g3hvMnYrA/   69   Mar 9, 2020
# 867   https://www.instagram.com/p/Ce3lI-uJF68/    8  Jun 16, 2022
# 197   https://www.instagram.com/p/CAkd0VfHSSD/   80  May 24, 2020
#
#                      author                   comment    id sentiment  \
# 33                crusshh07  Iiiiiii gemesshhhhhhhhhh  6715   Neutral
# 1311  pangestufirmanbudiana                       👍🙏🙏  5436   Neutral
# 102          puppypinnypigy               Aaa gemesss  6646  Positive
# 867            hendraken.22                  Ulangin😍  5882  Positive
# 197              ryntyptry_           Aing juga atuh💖  6551   Neutral
#
#       annotator  annotation_id                   created_at  \
# 33            1           1406  2022-08-02T13:00:14.930092Z
# 1311          1            128  2022-07-30T10:07:02.480412Z
# 102           1           1337  2022-08-02T12:52:31.341341Z
# 867           1            572  2022-08-01T11:41:37.268974Z
# 197           1           1242  2022-08-02T12:40:04.091321Z
#
#                        updated_at  lead_time                  cleaning  \
# 33    2022-08-02T13:00:14.930092Z      2.258  Iiiiiii gemesshhhhhhhhhh
# 1311  2022-07-30T10:07:02.480412Z      2.347
# 102   2022-08-02T12:52:31.341341Z      2.929               Aaa gemesss
# 867   2022-08-01T11:41:37.268974Z      1.819                  Ulangin
# 197   2022-08-02T12:40:04.091321Z      3.075           Aing juga atuh
#
#                    casefolding                   tokenizing  \
# 33    iiiiiii gemesshhhhhhhhhh  [iiiiiii, gemesshhhhhhhhhh]
# 1311                                                     []
# 102                aaa gemesss               [aaa, gemesss]
# 867                   ulangin                     [ulangin]
# 197            aing juga atuh            [aing, juga, atuh]
#
#                       normalisasi                     stopword  \
# 33    [iiiiiii, gemesshhhhhhhhhh]  [iiiiiii, gemesshhhhhhhhhh]
# 1311                           []                           []
# 102                  [aaa, gemas]                 [aaa, gemas]
# 867                     [ulangin]                    [ulangin]
# 197            [aing, juga, atuh]                 [aing, atuh]
#
#                          steeming                   cleaned
# 33    [iiiiiii, gemesshhhhhhhhhh]  iiiiiii gemesshhhhhhhhhh
# 1311                           []
# 102                  [aaa, gemas]                 aaa gemas
# 867                     [ulangin]                   ulangin
# 197                  [aing, atuh]                 aing atuh

# %%
# Proses pengubahan data kedalam bentuk csv ( buat folder data terlebih dahulu )
train.to_csv("./data/dataset_"+str(proportion)+"/cleaned_train.csv", index=False)
test.to_csv("./data/dataset_"+str(proportion)+"/cleaned_test.csv", index=False)

# train = pd.read_csv("./data/dataset_"+str(proportion)+"/cleaned_train.csv")
# test = pd.read_csv("./data/dataset_"+str(proportion)+"/cleaned_test.csv")
df.to_csv("./data/dataset_"+str(proportion)+"/cleaned_dataset.csv", index=False)
model_dump = {'train': train, 'test': test}
joblib.dump(model_dump, open("./data/dataset_"+str(proportion)+"/preprocessing"+".model", "wb"))

# %% [markdown]
# # Export Menjadi File CSV

# %%
filename = "./data/dataset_"+str(proportion)+"/hasil/Hasil_PreProcessing_Comment.csv"
df.to_csv(filename, index=False) #buat folder data terlebih dahulu

# %%
filename = "./data/dataset_"+str(proportion)+"/hasil/Hasil_PreProcessing_Comment.csv"
df.to_csv(filename, index=False)
